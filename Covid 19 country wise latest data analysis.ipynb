# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('C:/Users/user/OneDrive/Documents/CONCORDIA FILES/DATA SCIENCE/New folder/projet 1/country_wise_latest.csv')

# View the first few rows of the dataset
print(df.head())
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
# Checking for missing values in each column
print(df.isnull().sum())

# Filling missing values for numeric columns with 0, as missing values might represent lack of reported data
df.fillna(0, inplace=True)

# Checking data types to ensure everything is in the correct format
print(df.dtypes)

# Renaming columns to avoid any issues with special characters or spaces in column names
df.columns = ['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 
                'New_cases', 'New_deaths', 'New_recovered', 'Deaths_per_100_cases', 
                'Recovered_per_100_cases', 'Deaths_per_100_recovered', 
                'Confirmed_last_week', 'One_week_change', 'One_week_percent_increase', 
                'WHO_Region']

# Display cleaned data
df.head()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Confirmed Cases
plt.figure(figsize=(10,6))
sns.histplot(df['Confirmed'], bins=30, kde=True)
plt.title('Distribution of Confirmed COVID-19 Cases by Country')
plt.xlabel('Confirmed Cases')
plt.ylabel('Number of Countries')
plt.show()

# Top 10 Countries by Confirmed Cases
top_10_confirmed = df.nlargest(10, 'Confirmed')
plt.figure(figsize=(10,6))
sns.barplot(x='Confirmed', y='Country', df=top_10_confirmed)
plt.title('Top 10 Countries by Confirmed COVID-19 Cases')
plt.xlabel('Confirmed Cases')
plt.ylabel('Country')
plt.show()

# Scatter plot for Active Cases vs. Deaths
plt.figure(figsize=(10,6))
sns.scatterplot(x='Active', y='Deaths', data=data)
plt.title('Active Cases vs. Deaths by Country')
plt.xlabel('Active Cases')
plt.ylabel('Deaths')
plt.show()

# Confirmed Cases by WHO Region
plt.figure(figsize=(10,6))
sns.barplot(x='WHO_Region', y='Confirmed', data=data, estimator=sum, ci=None)
plt.title('Confirmed COVID-19 Cases by WHO Region')
plt.xlabel('WHO Region')
plt.ylabel('Total Confirmed Cases')
plt.xticks(rotation=45)
plt.show()
# Out:
# D:\user\Documents\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 15
#      13 top_10_confirmed = df.nlargest(10, 'Confirmed')
#      14 plt.figure(figsize=(10,6))
# ---> 15 sns.barplot(x='Confirmed', y='Country', df=top_10_confirmed)
#      16 plt.title('Top 10 Countries by Confirmed COVID-19 Cases')
#      17 plt.xlabel('Confirmed Cases')
#
# File D:\user\Documents\New folder\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
# ...

# %%
# Average number of deaths per country
average_deaths = df['Deaths'].mean()
print(f'The average number of deaths per country is: {average_deaths:.2f}')

# Countries with the highest 1-week % increase
top_5_increase = df.nlargest(5, 'One_week_percent_increase')[['Country', 'One_week_percent_increase', 'Confirmed']]
print('Top 5 Countries with the highest 1-week % increase in confirmed cases:')
print(top_5_increase)

# Correlation between Confirmed Cases and Deaths
correlation = df[['Confirmed', 'Deaths']].corr()
print('Correlation between Confirmed Cases and Deaths:')
print(correlation)

# Top 5 countries with the highest death rates (Deaths per 100 cases)
top_5_death_rate = df.nlargest(5, 'Deaths_per_100_cases')[['Country', 'Deaths_per_100_cases', 'Confirmed']]
print('Top 5 Countries with the highest death rates:')
print(top_5_death_rate)
# Out:
# The average number of deaths per country is: 3497.52
# Top 5 Countries with the highest 1-week % increase in confirmed cases:
#               Country  One_week_percent_increase  Confirmed
# 130  Papua New Guinea                     226.32         62
# 63             Gambia                     191.07        326
# 11            Bahamas                     119.54        382
# 186          Zimbabwe                      57.85       2704
# 99              Libya                      42.78       2827
# Correlation between Confirmed Cases and Deaths:
#            Confirmed    Deaths
# Confirmed   1.000000  0.934698
# Deaths      0.934698  1.000000
# Top 5 Countries with the highest death rates:
#             Country  Deaths_per_100_cases  Confirmed
# 184           Yemen                 28.56       1691
# 177  United Kingdom                 15.19     301708
# 16          Belgium                 14.79      66428
# 85            Italy                 14.26     246286
# ...

# %% [markdown]
# In conclusion, this analysis of the "country_wise_latest.csv" dataset revealed several important insights:
# - The average number of deaths per country i "s3497.9"].
# - The top 10 countries by confirmed cases incled" [list of countes"s].
# - Countrieskli"e [top couitr"es] have experienced significant increases in confirmed cases over the last week.
# - There is a strong positive correlation between confirmed cases and deaths, with some countriis
# - ke [top crunties] having higher death rates per 100 cases.
#
# Further analysis could explore the recovery rates and how they compare across regions, as well as tracking the spread over time.
